# %% [markdown]
# **ESTADISTICA APLICADA** - Grupo 51
#
# *SEGUNDO PARCIAL*
#
# Alumna: Erika Denisse Cardona Padilla
#
# Matricula: 1888872

# %%
#importamos las liberias
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
import statsmodels as sm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
#fijar el tamaño de las graficas
plt.rcParams['figure.figsize'] = [10, 7.5]

# %%
proceso = pd.read_csv('https://raw.githubusercontent.com/DenisseCardona/Tareas_EstadisticaAplicada_24/main/IGAE.csv?token=GHSAT0AAAAAABSHL5VME5XRVHUIJL3PK5XMYSBHMTQ',index_col='Periodo',parse_dates=True)
proceso.dropna(inplace=True)

# %%
plt.plot(proceso)
plt.title(r'proceso')
plt.show()

# %% [markdown]
# No es estacionaria ya que como podemos ver en la grafica hay un patrón nada mas de tendencia alcista
